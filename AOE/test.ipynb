# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math
from scipy.stats import chi2
from scipy.stats import poisson
import copy
import matplotlib as mpl
from matplotlib import cm

# %%
#ped1
date=[428,508,512,609,611,617]
num=np.array([i%100+(i/100)*30 for i in date])
ped1=np.array([[1.27e3,1.27e3,1.71e3,1.70e3,1.71e3,1.70e3],[1.51,1.64,1.90,1.79,1.77,1.71]])
ped2=np.array([[1.34e3,1.34e3,1.75e3,1.75e3,1.74e3,1.74e3],[1.46,2.02,1.99,1.83,2.35,2.14]])
ped=[ped1,ped2]

# %%
fig, ax = plt.subplots(1,1,figsize=(10, 6),dpi=1200)
num-=num[0]
for i in range(len(ped)):
    ax.errorbar(num,ped[i][0,:],yerr=ped[i][1,:],label='ped%d'%(i+1))
    ax.set(xlabel='days',ylabel='mean')
    ax.legend()
plt.show()

# %%
E=2039
cutoff=4710.4
delta=6.6
1-E/cutoff ,E/cutoff**2*delta
# Out:
# (0.5671280570652173, 0.0006065206401514872)
